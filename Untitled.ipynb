# %%
import pandas as pd

# %%
# df = pd.read_json('project_153_2021_05_05.json')

# %%
for i in df:
    print(i)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#                                           components  \
# 0  [{'uuid': 'efb18147-e027-49c8-93a7-15c77eefae6...
#
#                                            variables  \
# 0  [{'uuid': '2acdb21a-96df-4671-9a52-1c733e284e4...
#
#                                           dictionary  \
# 0  {'component_types': [{'id': 1, 'name': 'Вывод ...
#
#                                                lists
# 0  [{'id': 11786, 'order': 0, 'name': 'Новый лист...

# %%
import json
with open('project_153_2021_05_05.json','r') as f:
    data = json.loads(f.read())

# %%
data['components'][0]['data']['text']
# Out:
# 'Документы, необходимые для предоставления государственной услуги:\r\n1. Паспорт, подлежащий замене.\r\n2. Две (или четыре по желанию) личные фотографии в соответствии с требованиями МВД.'

# %%
data['components'][1]['data']['text']
# Out:
# '3. Квитанция об уплате государственной пошлины за замену паспорта в размере 300 рублей (не обязательна к предоставлению).\r\n4. Документы, необходимые для предоставления обязательных отметок в паспорте: военный билет (приписное удостоверение, справка из военкомата), свидетельства о рождении детей - граждан РФ в возрасте до 14-ти лет, свидетельство о регистрации брака, свидетельство о расторжении брака (не обязательно к предоставлению в случае наличия соответствующих отметок в паспорте).'

# %%
data
# Out:
# {'components': [{'uuid': 'efb18147-e027-49c8-93a7-15c77eefae65',
#    'parent_uuids': ['4cd9f2f6-e766-4b52-97e2-2b93f69c64e0'],
#    'component_type_code': 'text',
#    'order': 4980,
#    'platforms': [],
#    'data': {'text': 'Документы, необходимые для предоставления государственной услуги:\r\n1. Паспорт, подлежащий замене.\r\n2. Две (или четыре по желанию) личные фотографии в соответствии с требованиями МВД.',
#     'type': 'text',
#     'buttons': [],
#     'preview_link': True},
#    'x': -10768,
#    'y': -2352,
#    'is_main': False,
#    'is_expand': True,
#    'enable': True},
#   {'uuid': 'a9921c77-a71a-446f-8600-52d63ef27bb6',
#    'parent_uuids': ['efb18147-e027-49c8-93a7-15c77eefae65'],
#    'component_type_code': 'text',
#    'order': 4981,
#    'platforms': [],
# ...

# %%
# dir(json)

# %%
# json.

# %%
# for i, obj in enumerate(json):
#     print(obj)
#     if i == 5: break

# %%
# jsn.read

# %%
# import json

# jsn = open('project_153_2021_05_05.json', 'r')
# txt = json.loads(jsn.read(1))

# %%
import os
os.name
# Out:
# 'posix'

# %%
os.getcwd()
# Out:
# '/home/user/src/диплом/Чат-бот'

# %%
os.listdir()
# Out:
# ['.ipynb_checkpoints',
#  'project_153_2021_05_05.json',
#  'project_153_2021_05_05_tilda5086602.rar',
#  'Untitled.ipynb']

# %%
import json

# %%
with open('cat.json') as file:
    data = file.read()
    data = json.loads(data)
    for i in data:
        print(i)
# Out:
# {'name': 'Barsik', 'age': 7, 'meals': ['Wiskas', 'Royal Canin', 'Purina', 'Hills', 'Brit Care']}
# {'name': 'Mursik', 'age': 3, 'meals': ['Purina', 'Hills', 'Brit Care']}

# %%
# !wc -l project_153_2021_05_05.json
# Out:
# 0 project_153_2021_05_05.json

# %%
count_lines = sum(1 for line in open('project_153_2021_05_05.json'))
count_lines

# %%
# !split -l  project_153_2021_05_05.json

# %%
# !cat project_153_2021_05_05.json | jq length

# %%
# !less project_153_2021_05_05.json
# Out:
# "project_153_2021_05_05.json" may be a binary file.  See it anyway?

# %%
# !pip install ijson
# Out:
# ...
#      |████████████████████████████████| 133 kB 251 kB/s eta 0:00:01
# ...

# %%
# import ijson
# f = open('xaa', 'rb')
# for id in ijson.items(f, 'earth.europe.item'):
#     print(id)
#     break

# %%
# !wc -l xaa
# Out:
# 0 xaa

# %%
# with open('xaa', 'rb') as file:
#     data = file.read()
#     data = json.loads(data)
#     for i in data:
#         print(i)

# %%
# import pandas as pd
# import json

# with open('project_153_2021_05_05.json', 'rb') as f:
#     df = pd.DataFrame(json.loads(line) for line in f)
