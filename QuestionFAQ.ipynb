# %%
# !pip install deeppavlov
# Out:
# ...
#      |████████████████████████████████| 929 kB 5.3 MB/s
# ...
#      |████████████████████████████████| 7.3 MB 15.1 MB/s
# ...
#      |████████████████████████████████| 654 kB 51.8 MB/s
# ...
#      |████████████████████████████████| 40 kB 17 kB/s
# ...
#      |████████████████████████████████| 2.1 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 10.6 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 47.5 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.8 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.8 MB/s
# ...
#      |████████████████████████████████| 10.4 MB 47.2 MB/s
# ...
#      |████████████████████████████████| 6.7 MB 51.8 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 50.4 MB/s
# ...
#      |████████████████████████████████| 510 kB 12.7 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.2 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.9 MB/s
# ...

# %%
# dir(deeppavlov.contrib)

# %%
# from deeppavlov.contrib.skills.similarity_matching_skill import SimilarityMatchingSkill
# faq = SimilarityMatchingSkill(data_path = 'http://files.deeppavlov.ai/faq/dataset_ru.csv',
#                               x_col_name = 'Question', 
#                               y_col_name = 'Answer',
#                               save_load_path = './model',
#                               config_type = 'tfidf_autofaq',
#                               edit_dict = {},
#                               train = True)
# faq = SimilarityMatchingSkill(save_load_path='./model') 
# faq(["где будет школа?"],[],[])

# %%
# !pip install pandas==1.2
# Out:
# ...
#      |████████████████████████████████| 9.9 MB 5.0 MB/s
# ...
#   Attempting uninstall: pandas
#     Found existing installation: pandas 0.25.3
#     Uninstalling pandas-0.25.3:
#       Successfully uninstalled pandas-0.25.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas~=1.1.0; python_version >= "3.0", but you have pandas 1.2.0 which is incompatible.
# google-colab 1.0.0 requires requests~=2.23.0, but you have requests 2.22.0 which is incompatible.
# deeppavlov 0.17.1 requires pandas==0.25.3, but you have pandas 1.2.0 which is incompatible.
# ...

# %%
import pandas as pd
pd.read_csv('data_faq_mfc.csv', sep=',')
# Out:
#                                               Question                                             Answer
# 0    какой документ о вознаграждении подойдёт для о...  Здравствуйте! Вам необходимо предоставить доку...
# 1    Здравствуйте сайт для проверки очереди не рабо...  Здравствуйте! Информацию о статусе рассмотрени...
# 2    Добрый день . Подавали документы на выплаты до...  Здравствуйте! О статусе рассмотрения заявления...
# 3    Здравствуйте подскажите пожалуйста подавала на...  Здравствуйте! В МФЦ результат не возвращается....
# 4    Выдача результатов завершена обращение готово ...  Здравствуйте! Статус Вашего дела – «В архиве»....
# ..                                                 ...                                                ...
# 859  Добрый день! Какие необходимы документы чтобы ...  Здравствуйте просим Вас обратиться в региональ...
# 860  Здравствуйтеподскажите как быть ? Сдала в МФЦ ...  Здравствуйте просим Вас обратиться в региональ...
# ...

# %%
# from deeppavlov.core.common.file import read_json
import pandas as pd
model_config = pd.read_csv('MFC_data.csv', sep=';')

# %%
model_config.columns
# Out:
# Index(['Дата обращения', 'Вопрос', 'Ответ', 'Ссылка'], dtype='object')

# %%
df = model_config[['Вопрос', 'Ответ']]

# %%
df.head()
# Out:
#                                               Вопрос                                              Ответ
# 0  ,,какой документ о вознаграждении подойдёт для...  Здравствуйте! Вам необходимо предоставить доку...
# 1  Здравствуйте сайт для проверки очереди не рабо...  Здравствуйте! Информацию о статусе рассмотрени...
# 2  Добрый день . Подавали документы на выплаты до...  Здравствуйте! О статусе рассмотрения заявления...
# 3  Здравствуйте подскажите пожалуйста подавала на...  Здравствуйте! В МФЦ результат не возвращается....
# 4  Выдача результатов завершена, обращение готово...  Здравствуйте! Статус Вашего дела – «В архиве»....

# %%
# # compression_opts = dict(method='zip', archive_name='out.csv')
# df.to_csv('out.csv', sep='\t', index=False)

# %%
from deeppavlov import train_model, build_model
from deeppavlov.core.common.file import read_json
model_config = read_json('idf.json')
# изменить model_config data_path 
model = train_model(model_config)  # или build_model(model_config)
# Out:
# 2021-10-03 15:30:03.83 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 203: Loading model sklearn.feature_extraction.text:TfidfVectorizer from /root/.deeppavlov/models/vectorizer/tfidf_vectorizer_ruwiki.pkl
# 2021-10-03 15:30:03.88 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 210: Model sklearn.feature_extraction.textTfidfVectorizer loaded  with parameters
# 2021-10-03 15:30:03.90 WARNING in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 216: Fitting of loaded model can not be continued. Model can be fitted from scratch.If one needs to continue fitting, please, look at `warm_start` parameter
# 2021-10-03 15:30:03.855 INFO in 'deeppavlov.models.sklearn.sklearn_component'['sklearn_component'] at line 109: Fitting model sklearn.feature_extraction.textTfidfVectorizer
# ...

# %%
answers, probability = model(['Как получить свидетельство о расторжении брака из другого города, просто нет возможности приехать?'])

# %%
answers
# Out:
# ['Здравствуйте! Рекомендуем Вам обратиться в отделение ЗАГС по месту Вашего фактического нахождения.']

# %%
probability
# Out:
# [0.02]

# %%
model(['Как получить свидетельство о расторжении брака из другого города, просто нет возможности приехать?'])
# Out:
# [['Здравствуйте! Рекомендуем Вам обратиться в отделение ЗАГС по месту Вашего фактического нахождения.',
#   'Здравствуйте! В Отделениях МФЦ предоставляются услуги:\n1.\xa0\xa0\xa0\xa0«Прием заявления о выдаче повторного свидетельства о государственной регистрации акта гражданского состояния или иного документа подтверждающего наличие либо отсутствие факта государственной регистрации акта гражданского состояния и их выдача»;\n2.\xa0\xa0\xa0\xa0«Государственная регистрация расторжения брака по взаимному согласию супругов не имеющих общих несовершеннолетних детей (в части приема заявления о предоставлении государственной услуги)».\nДополнительную информацию Вы можете получить по телефону регионального колл-центра МФЦ: 8 (4162) 99 22 22.'],
#  [0.04, 0.03]]

# %%
# !pip install deeppavlov
# Out:
# ...
#      |████████████████████████████████| 928 kB 5.2 MB/s
# ...
#      |████████████████████████████████| 859 kB 36.5 MB/s
# ...
#      |████████████████████████████████| 53 kB 2.4 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 1.5 MB 43.2 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 46.2 MB/s
# ...
#      |████████████████████████████████| 40 kB 21 kB/s
# ...
#      |████████████████████████████████| 7.3 MB 48.5 MB/s
# ...
#      |████████████████████████████████| 20.1 MB 76.4 MB/s
# ...
#      |████████████████████████████████| 3.8 MB 47.7 MB/s
# ...
#      |████████████████████████████████| 10.4 MB 32.9 MB/s
# ...
#      |████████████████████████████████| 654 kB 39.4 MB/s
# ...
#      |████████████████████████████████| 510 kB 59.9 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 43 kB 1.8 MB/s
# ...
#      |████████████████████████████████| 43 kB 2.0 MB/s
# ...
#      |████████████████████████████████| 2.9 MB 33.6 MB/s
# ...

# %%
# !python3 -m deeppavlov interact rusentiment_bert -d
# Out:
# 2021-09-26 13:58:14.442 INFO in 'deeppavlov.core.common.file'['file'] at line 32: Interpreting 'rusentiment_bert' as '/usr/local/lib/python3.7/dist-packages/deeppavlov/configs/classifiers/rusentiment_bert.json'
# 2021-09-26 13:58:16.120 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/deeppavlov_data/bert/multi_cased_L-12_H-768_A-12.zip?config=rusentiment_bert to /root/.deeppavlov/downloads/multi_cased_L-12_H-768_A-12.zip
# 100% 663M/663M [02:21<00:00, 4.67MB/s]
# 2021-09-26 14:00:38.879 INFO in 'deeppavlov.core.data.utils'['utils'] at line 272: Extracting /root/.deeppavlov/downloads/multi_cased_L-12_H-768_A-12.zip archive into /root/.deeppavlov/downloads/bert_models
# 2021-09-26 14:00:46.661 INFO in 'deeppavlov.core.data.utils'['utils'] at line 95: Downloading from http://files.deeppavlov.ai/deeppavlov_data/classifiers/rusentiment_bert_v0.tar.gz?config=rusentiment_bert to /root/.deeppavlov/models/rusentiment_bert_v0.tar.gz
# ...
